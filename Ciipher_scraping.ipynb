# %% [markdown]
# # Trending Now | K-idol Group Ciipher Tweet Scraping

# %%
from tweetkey import consumer_api_key, consumer_api_secret_key, access_token, access_secret_token

# %%
import tweepy
import pandas as pd
import time

# %%
auth = tweepy.OAuthHandler(consumer_api_key, consumer_api_secret_key)
auth.set_access_token(access_token, access_secret_token)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
Ciipher_tweets = tweepy.Cursor(api.search, q='Ciipher', result_type='mixed').items(150)
    
Ciipher_tweets_list = [[Ciipher_tweet.created_at, Ciipher_tweet.id, Ciipher_tweet.text, 
                      Ciipher_tweet.favorite_count] 
                     for Ciipher_tweet in Ciipher_tweets
                    ]
    
Ciipher_tweets_df = pd.DataFrame(Ciipher_tweets_list)

# %%
Ciipher_tweets_df
# Out:
#                       0                    1  \
# 0   2021-05-20 06:40:38  1395268209549266944
# 1   2021-05-20 09:00:20  1395303365656018944
# 2   2021-05-21 07:30:17  1395643091676135427
# 3   2021-05-21 17:23:37  1395792410161016833
# 4   2021-05-21 17:22:46  1395792193185406981
# ..                  ...                  ...
# 145 2021-05-20 04:49:10  1395240158711017481
# 146 2021-05-20 04:48:58  1395240108903714819
# 147 2021-05-20 04:46:26  1395239471344402435
# 148 2021-05-20 04:45:58  1395239352028991493
# 149 2021-05-20 04:41:54  1395238329814114307
#
#                                                      2     3
# 0    [#태그]\n\n곰태그\n다들 손 잘 씻고 계시죠?🐻\n\n#Ciipher #싸이퍼...  6363
# 1    [#CPR] 싸이퍼(Ciipher) 도환 'Shawn Mendes - In My B...  2939
# 2    [#CPR] #현빈 #원\n#TikTok #변신챌린지 영상 도착💌\n\n싸이퍼 틱톡...  1897
# 3    RT @CPR_won_land: 210520 네이버나우 로얄코믹스 원🐰\n\n손인사...     0
# 4    @lovelinmo I HAVEN'T KEPT UP WITH ANY OF THEM ...     0
# ...

# %%
cleaned_Ciipher_tweets_df = Ciipher_tweets_df.drop([1], axis = 1)
# cleaned_Ciipher_tweets_df

new_Ciipher_tweets_df = cleaned_Ciipher_tweets_df.rename(columns={0: "Tweeted Date", 2: "Tweet Description", 3: "Popularity Count"})
# new_Ciipher_tweets_df

sort_Ciipher_tweets_df = new_Ciipher_tweets_df.sort_values(by="Popularity Count", ascending=False)
sort_Ciipher_tweets_df
# Out:
#            Tweeted Date                                  Tweet Description  \
# 0   2021-05-20 06:40:38  [#태그]\n\n곰태그\n다들 손 잘 씻고 계시죠?🐻\n\n#Ciipher #싸이퍼...
# 1   2021-05-20 09:00:20  [#CPR] 싸이퍼(Ciipher) 도환 'Shawn Mendes - In My B...
# 2   2021-05-21 07:30:17  [#CPR] #현빈 #원\n#TikTok #변신챌린지 영상 도착💌\n\n싸이퍼 틱톡...
# 128 2021-05-20 05:04:18  #prupdates \nAstro Broadcast PCs have arrived!...
# 33  2021-05-20 06:27:37  my favorite boy \n#원 #CIIPHER #싸이퍼 #박성원   #PAR...
# ..                  ...                                                ...
# 46  2021-05-20 06:04:26  RT @zunhwwww: ขออนุญาตเชิญชวนทุกคนมาฟัง #안꿀려 ข...
# 45  2021-05-20 06:04:55  RT @RAIN_Ciipher: [#휘] 피크닉 간 느낌이여서 좋았던 날💕\n\n#...
# 44  2021-05-20 06:04:58  RT @RAIN_Ciipher: [#휘] 싸이퍼 사랑둥이들💕\n\n#Ciipher ...
# 43  2021-05-20 06:05:03  RT @zunhwwww: ขออนุญาตเชิญชวนทุกคนมาฟัง #안꿀려 ข...
# 149 2021-05-20 04:41:54  RT @PURPLEMOON_1218: 210519 전국춘향선발대회 \n\n행사는 최...
#
#      Popularity Count
# 0                6363
# ...

# %%
sort_Ciipher_tweets_df["Tweeted Date"] = pd.to_datetime(sort_Ciipher_tweets_df["Tweeted Date"]).dt.date

# %%
sort_Ciipher_tweets_df.head()
# Out:
#     Tweeted Date                                  Tweet Description  \
# 0     2021-05-20  [#태그]\n\n곰태그\n다들 손 잘 씻고 계시죠?🐻\n\n#Ciipher #싸이퍼...
# 1     2021-05-20  [#CPR] 싸이퍼(Ciipher) 도환 'Shawn Mendes - In My B...
# 2     2021-05-21  [#CPR] #현빈 #원\n#TikTok #변신챌린지 영상 도착💌\n\n싸이퍼 틱톡...
# 128   2021-05-20  #prupdates \nAstro Broadcast PCs have arrived!...
# 33    2021-05-20  my favorite boy \n#원 #CIIPHER #싸이퍼 #박성원   #PAR...
#
#      Popularity Count
# 0                6363
# 1                2939
# 2                1897
# 128                19
# 33                 11

# %%
sort_Ciipher_tweets_df.tail()
# Out:
#     Tweeted Date                                  Tweet Description  \
# 46    2021-05-20  RT @zunhwwww: ขออนุญาตเชิญชวนทุกคนมาฟัง #안꿀려 ข...
# 45    2021-05-20  RT @RAIN_Ciipher: [#휘] 피크닉 간 느낌이여서 좋았던 날💕\n\n#...
# 44    2021-05-20  RT @RAIN_Ciipher: [#휘] 싸이퍼 사랑둥이들💕\n\n#Ciipher ...
# 43    2021-05-20  RT @zunhwwww: ขออนุญาตเชิญชวนทุกคนมาฟัง #안꿀려 ข...
# 149   2021-05-20  RT @PURPLEMOON_1218: 210519 전국춘향선발대회 \n\n행사는 최...
#
#      Popularity Count
# 46                  0
# 45                  0
# 44                  0
# 43                  0
# 149                 0

# %%
sort_Ciipher_tweets_df.to_csv('files/ciipher_scraping.csv')
