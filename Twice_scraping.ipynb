# %%
# Import tweetkey and other necessary dependencies
from tweetkey import consumer_api_key, consumer_api_secret_key, access_token, access_secret_token

import tweepy
import pandas as pd
import time

# %%
# Authorize the tweepy with OAuthHandler method from tweepy documentation 
# Set up my access token
auth = tweepy.OAuthHandler(consumer_api_key, consumer_api_secret_key)
auth.set_access_token(access_token, access_secret_token)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# Search the query by the artist group name and show the results for popular and recent ones up to 150 items

twice_tweets = tweepy.Cursor(api.search, q='TWICE', result_type='mixed').items(150)
    
twice_tweets_list = [[twice_tweet.created_at, twice_tweet.id, twice_tweet.text, 
                      twice_tweet.favorite_count] 
                     for twice_tweet in twice_tweets
                    ]
    
twice_tweets_df = pd.DataFrame(twice_tweets_list)

# %%
# Show the list of the tweets
twice_tweets_df
# Out:
#                       0                    1  \
# 0   2021-05-10 01:17:56  1391563119055446016
# 1   2021-05-10 12:00:14  1391724762347409410
# 2   2021-05-10 09:00:00  1391679403231518721
# 3   2021-05-11 00:00:53  1391906117790273536
# 4   2021-05-11 00:00:52  1391906113247920131
# ..                  ...                  ...
# 145 2021-05-10 01:17:42  1391563060238770176
# 146 2021-05-10 01:17:42  1391563060024729600
# 147 2021-05-10 01:17:41  1391563058644865025
# 148 2021-05-10 01:17:41  1391563058540158978
# 149 2021-05-10 01:17:41  1391563058519044099
#
#                                                      2      3
# 0    TWICE\nThe 10th Mini Album\n&lt;Taste of Love&...  65954
# 1    TWICEメンバーによる『Kura Kura』メッセージが届きました♪\n\n#Day9\n...  41046
# 2    今週のMステは…\n5月14日（金）よる21時から📺⚡️\n\n石崎ひゅーい/東京事変/TW...  12679
# 3    RT @TWICESTATS: we will not make any trending ...      0
# 4    RT @GeminiTerms: #Gemini don’t pick fights, &a...      0
# ...

# %%
cleaned_twice_tweets_df = twice_tweets_df.drop([1], axis = 1)
# cleaned_twice_tweets_df

new_twice_tweets_df = cleaned_twice_tweets_df.rename(columns={0: "Tweeted Date", 2: "Tweet Description", 3: "Popularity Count"})
# new_twice_tweets_df

sort_twice_tweets_df = new_twice_tweets_df.sort_values(by="Popularity Count", ascending=False)
sort_twice_tweets_df
# Out:
#            Tweeted Date                                  Tweet Description  \
# 0   2021-05-10 01:17:56  TWICE\nThe 10th Mini Album\n&lt;Taste of Love&...
# 1   2021-05-10 12:00:14  TWICEメンバーによる『Kura Kura』メッセージが届きました♪\n\n#Day9\n...
# 2   2021-05-10 09:00:00  今週のMステは…\n5月14日（金）よる21時から📺⚡️\n\n石崎ひゅーい/東京事変/TW...
# 73  2021-05-10 01:17:50  Kalani disgusts me she treats Asuelu like he’s...
# 91  2021-05-10 01:17:48  (PH GO) #MSPH7GO\n\nTWICE TASTE OF LOVE\n💜KTOW...
# ..                  ...                                                ...
# 52  2021-05-10 01:17:52  RT @TWICEANALYTICS: Fastest TWICE Japanese son...
# 53  2021-05-10 01:17:52  RT @knkshoppeph: [PH GIVEAWAY] TWICE 10th Mini...
# 54  2021-05-10 01:17:52  @tzyui_ PRE ORDER TASTE OF LOVE\n#PreOrder_Tas...
# 55  2021-05-10 01:17:52  RT @TwiceNest: TWICE\nThe 10th Mini Album\n&lt...
# 149 2021-05-10 01:17:41  @BarkoNgALE @JYPETWICE PREORDER TASTE OF LOVE\...
#
#      Popularity Count
# 0               65954
# ...
